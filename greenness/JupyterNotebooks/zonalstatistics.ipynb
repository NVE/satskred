# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn.objects as so

sns.set_theme
# Out:
# <function seaborn.rcmod.set_theme(context='notebook', style='darkgrid', palette='deep', font='sans-serif', font_scale=1, color_codes=True, rc=None)>

# %%
cols = ['_count', '_sum']

# %% [markdown]
# #### Zone 1 - Region 1011 Romsdal

# %%
Z1_030420_A3_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z1_030420_A3_Romsdal.csv')
Z1_030420_A4_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z1_030420_A4_Romsdal.csv')
Z1_030420_A5_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z1_030420_A5_Romsdal.csv')
Z1_030420_A6_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z1_030420_A6_Romsdal.csv')
Z1_030420_A7_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z1_030420_A7_Romsdal.csv')
Z1_030420_A8_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z1_030420_A8_Romsdal.csv')

Z1_030520_A3_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z1_030520_A3_Romsdal.csv')
Z1_030520_A4_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z1_030520_A4_Romsdal.csv')
Z1_030520_A5_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z1_030520_A5_Romsdal.csv')
Z1_030520_A6_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z1_030520_A6_Romsdal.csv')
Z1_030520_A7_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z1_030520_A7_Romsdal.csv')
Z1_030520_A8_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z1_030520_A8_Romsdal.csv')

Z1_140520_A3_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z1_140520_A3_Romsdal.csv')
Z1_140520_A4_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z1_140520_A4_Romsdal.csv')
Z1_140520_A5_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z1_140520_A5_Romsdal.csv')
Z1_140520_A6_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z1_140520_A6_Romsdal.csv')
Z1_140520_A7_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z1_140520_A7_Romsdal.csv')
Z1_140520_A8_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z1_140520_A8_Romsdal.csv')

Z1_100120_A3_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z1_100120_A3_Romsdal.csv')
Z1_100120_A4_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z1_100120_A4_Romsdal.csv')
Z1_100120_A5_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z1_100120_A5_Romsdal.csv')
Z1_100120_A6_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z1_100120_A6_Romsdal.csv')
Z1_100120_A7_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z1_100120_A7_Romsdal.csv')
Z1_100120_A8_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z1_100120_A8_Romsdal.csv')

Z1_270520_A3_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z1_270520_A3_Romsdal.csv')
Z1_270520_A4_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z1_270520_A4_Romsdal.csv')
Z1_270520_A5_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z1_270520_A5_Romsdal.csv')
Z1_270520_A6_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z1_270520_A6_Romsdal.csv')
Z1_270520_A7_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z1_270520_A7_Romsdal.csv')
Z1_270520_A8_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z1_270520_A8_Romsdal.csv')

Z1_140220_A3_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z1_140220_A3_Romsdal.csv')
Z1_140220_A4_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z1_140220_A4_Romsdal.csv')
Z1_140220_A5_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z1_140220_A5_Romsdal.csv')
Z1_140220_A6_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z1_140220_A6_Romsdal.csv')
Z1_140220_A7_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z1_140220_A7_Romsdal.csv')
Z1_140220_A8_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z1_140220_A8_Romsdal.csv')

# %%
print(Z1_030420_A3_Romsdal[cols].sum())
print(Z1_030420_A4_Romsdal[cols].sum())
print(Z1_030420_A5_Romsdal[cols].sum())
print(Z1_030420_A6_Romsdal[cols].sum())
print(Z1_030420_A7_Romsdal[cols].sum())
print(Z1_030420_A8_Romsdal[cols].sum())

print(Z1_030520_A3_Romsdal[cols].sum())
print(Z1_030520_A4_Romsdal[cols].sum())
print(Z1_030520_A5_Romsdal[cols].sum())
print(Z1_030520_A6_Romsdal[cols].sum())
print(Z1_030520_A7_Romsdal[cols].sum())
print(Z1_030520_A8_Romsdal[cols].sum())

print(Z1_140520_A3_Romsdal[cols].sum())
print(Z1_140520_A4_Romsdal[cols].sum())
print(Z1_140520_A5_Romsdal[cols].sum())
print(Z1_140520_A6_Romsdal[cols].sum())
print(Z1_140520_A7_Romsdal[cols].sum())
print(Z1_140520_A8_Romsdal[cols].sum())

print(Z1_100120_A3_Romsdal[cols].sum())
print(Z1_100120_A4_Romsdal[cols].sum())
print(Z1_100120_A5_Romsdal[cols].sum())
print(Z1_100120_A6_Romsdal[cols].sum())
print(Z1_100120_A7_Romsdal[cols].sum())
print(Z1_100120_A8_Romsdal[cols].sum())

print(Z1_270520_A3_Romsdal[cols].sum())
print(Z1_270520_A4_Romsdal[cols].sum())
print(Z1_270520_A5_Romsdal[cols].sum())
print(Z1_270520_A6_Romsdal[cols].sum())
print(Z1_270520_A7_Romsdal[cols].sum())
print(Z1_270520_A8_Romsdal[cols].sum())

print(Z1_140220_A3_Romsdal[cols].sum())
print(Z1_140220_A4_Romsdal[cols].sum())
print(Z1_140220_A5_Romsdal[cols].sum())
print(Z1_140220_A6_Romsdal[cols].sum())
print(Z1_140220_A7_Romsdal[cols].sum())
print(Z1_140220_A8_Romsdal[cols].sum())
# Out:
# _count    246143.000000
# _sum       17380.796828
# dtype: float64
# _count    241292.000000
# _sum       16817.939834
# dtype: float64
# _count    87927.000000
# _sum       6962.358553
# dtype: float64
# _count    57382.000000
# _sum       9891.724567
# dtype: float64
# _count    92336.000000
# _sum       5579.563331
# dtype: float64
# _count    35151.000000
# _sum       2419.362844
# dtype: float64
# _count    225443.000000
# _sum        3583.719133
# dtype: float64
# _count    216332.000000
# _sum      -28659.533633
# dtype: float64
# _count    81207.000000
# _sum      -7515.841343
# dtype: float64
# _count    46161.000000
# _sum      -4614.787795
# dtype: float64
# _count    85067.000000
# _sum      -8523.379083
# dtype: float64
# _count    33115.000000
# _sum       1168.978219
# dtype: float64
# _count    216726.000000
# _sum      -60895.734542
# dtype: float64
# _count    205745.000000
# _sum       35873.681389
# dtype: float64
# _count    75398.000000
# _sum         55.711079
# ...

# %% [markdown]
# #### Zone 2 - Region 1011 Romsdal

# %%
Z2_030420_A3_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z2_030420_A3_Romsdal.csv')
Z2_030420_A4_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z2_030420_A4_Romsdal.csv')
Z2_030420_A5_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z2_030420_A5_Romsdal.csv')
Z2_030420_A6_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z2_030420_A6_Romsdal.csv')
Z2_030420_A7_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z2_030420_A7_Romsdal.csv')
Z2_030420_A8_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z2_030420_A8_Romsdal.csv')

Z2_030520_A3_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z2_030520_A3_Romsdal.csv')
Z2_030520_A4_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z2_030520_A4_Romsdal.csv')
Z2_030520_A5_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z2_030520_A5_Romsdal.csv')
Z2_030520_A6_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z2_030520_A6_Romsdal.csv')
Z2_030520_A7_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z2_030520_A7_Romsdal.csv')
Z2_030520_A8_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z2_030520_A8_Romsdal.csv')

Z2_140520_A3_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z2_140520_A3_Romsdal.csv')
Z2_140520_A4_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z2_140520_A4_Romsdal.csv')
Z2_140520_A5_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z2_140520_A5_Romsdal.csv')
Z2_140520_A6_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z2_140520_A6_Romsdal.csv')
Z2_140520_A7_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z2_140520_A7_Romsdal.csv')
Z2_140520_A8_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z2_140520_A8_Romsdal.csv')

Z2_100120_A3_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z2_100120_A3_Romsdal.csv')
Z2_100120_A4_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z2_100120_A4_Romsdal.csv')
Z2_100120_A5_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z2_100120_A5_Romsdal.csv')
Z2_100120_A6_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z2_100120_A6_Romsdal.csv')
Z2_100120_A7_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z2_100120_A7_Romsdal.csv')
Z2_100120_A8_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z2_100120_A8_Romsdal.csv')

Z2_270520_A3_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z2_270520_A3_Romsdal.csv')
Z2_270520_A4_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z2_270520_A4_Romsdal.csv')
Z2_270520_A5_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z2_270520_A5_Romsdal.csv')
Z2_270520_A6_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z2_270520_A6_Romsdal.csv')
Z2_270520_A7_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z2_270520_A7_Romsdal.csv')
Z2_270520_A8_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z2_270520_A8_Romsdal.csv')

Z2_140220_A3_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z2_140220_A3_Romsdal.csv')
Z2_140220_A4_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z2_140220_A4_Romsdal.csv')
Z2_140220_A5_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z2_140220_A5_Romsdal.csv')
Z2_140220_A6_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z2_140220_A6_Romsdal.csv')
Z2_140220_A7_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z2_140220_A7_Romsdal.csv')
Z2_140220_A8_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z2_140220_A8_Romsdal.csv')

# %%
print(Z2_030420_A3_Romsdal[cols].sum())
print(Z2_030420_A4_Romsdal[cols].sum())
print(Z2_030420_A5_Romsdal[cols].sum())
print(Z2_030420_A6_Romsdal[cols].sum())
print(Z2_030420_A7_Romsdal[cols].sum())
print(Z2_030420_A8_Romsdal[cols].sum())

print(Z2_030520_A3_Romsdal[cols].sum())
print(Z2_030520_A4_Romsdal[cols].sum())
print(Z2_030520_A5_Romsdal[cols].sum())
print(Z2_030520_A6_Romsdal[cols].sum())
print(Z2_030520_A7_Romsdal[cols].sum())
print(Z2_030520_A8_Romsdal[cols].sum())

print(Z2_140520_A3_Romsdal[cols].sum())
print(Z2_140520_A4_Romsdal[cols].sum())
print(Z2_140520_A5_Romsdal[cols].sum())
print(Z2_140520_A6_Romsdal[cols].sum())
print(Z2_140520_A7_Romsdal[cols].sum())
print(Z2_140520_A8_Romsdal[cols].sum())

print(Z2_100120_A3_Romsdal[cols].sum())
print(Z2_100120_A4_Romsdal[cols].sum())
print(Z2_100120_A5_Romsdal[cols].sum())
print(Z2_100120_A6_Romsdal[cols].sum())
print(Z2_100120_A7_Romsdal[cols].sum())
print(Z2_100120_A8_Romsdal[cols].sum())

print(Z2_270520_A3_Romsdal[cols].sum())
print(Z2_270520_A4_Romsdal[cols].sum())
print(Z2_270520_A5_Romsdal[cols].sum())
print(Z2_270520_A6_Romsdal[cols].sum())
print(Z2_270520_A7_Romsdal[cols].sum())
print(Z2_270520_A8_Romsdal[cols].sum())

print(Z2_140220_A3_Romsdal[cols].sum())
print(Z2_140220_A4_Romsdal[cols].sum())
print(Z2_140220_A5_Romsdal[cols].sum())
print(Z2_140220_A6_Romsdal[cols].sum())
print(Z2_140220_A7_Romsdal[cols].sum())
print(Z2_140220_A8_Romsdal[cols].sum())
# Out:
# _count    324813.143268
# _sum       28995.089573
# dtype: float64
# _count    162535.761603
# _sum       25789.702180
# dtype: float64
# _count    415696.574125
# _sum       41587.779076
# dtype: float64
# _count    274024.634345
# _sum       41586.355255
# dtype: float64
# _count    119578.716387
# _sum       10807.985567
# dtype: float64
# _count    78078.289190
# _sum       6563.800701
# dtype: float64
# _count    301903.384197
# _sum       -5415.970717
# dtype: float64
# _count    137754.184682
# _sum      -20071.834384
# dtype: float64
# _count    389835.592415
# _sum      -32635.145094
# dtype: float64
# _count    229501.202535
# _sum      -23276.717081
# dtype: float64
# _count    104403.750022
# _sum       -3627.935368
# dtype: float64
# _count    72771.454444
# _sum       -864.931087
# dtype: float64
# _count    283161.975657
# _sum      -44101.573952
# dtype: float64
# _count    126017.164066
# _sum       15528.160427
# dtype: float64
# _count    353572.433373
# ...

# %% [markdown]
# #### Zone 3 - Region 1011 Romsdal

# %%
Z3_030420_A3_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z3_030420_A3_Romsdal.csv')
Z3_030420_A4_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z3_030420_A4_Romsdal.csv')
Z3_030420_A5_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z3_030420_A5_Romsdal.csv')
Z3_030420_A6_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z3_030420_A6_Romsdal.csv')
Z3_030420_A7_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z3_030420_A7_Romsdal.csv')
Z3_030420_A8_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z3_030420_A8_Romsdal.csv')

Z3_030520_A3_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z3_030520_A3_Romsdal.csv')
Z3_030520_A4_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z3_030520_A4_Romsdal.csv')
Z3_030520_A5_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z3_030520_A5_Romsdal.csv')
Z3_030520_A6_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z3_030520_A6_Romsdal.csv')
Z3_030520_A7_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z3_030520_A7_Romsdal.csv')
Z3_030520_A8_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z3_030520_A8_Romsdal.csv')

Z3_140520_A3_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z3_140520_A3_Romsdal.csv')
Z3_140520_A4_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z3_140520_A4_Romsdal.csv')
Z3_140520_A5_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z3_140520_A5_Romsdal.csv')
Z3_140520_A6_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z3_140520_A6_Romsdal.csv')
Z3_140520_A7_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z3_140520_A7_Romsdal.csv')
Z3_140520_A8_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z3_140520_A8_Romsdal.csv')

Z3_100120_A3_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z3_100120_A3_Romsdal.csv')
Z3_100120_A4_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z3_100120_A4_Romsdal.csv')
Z3_100120_A5_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z3_100120_A5_Romsdal.csv')
Z3_100120_A6_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z3_100120_A6_Romsdal.csv')
Z3_100120_A7_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z3_100120_A7_Romsdal.csv')
Z3_100120_A8_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z3_100120_A8_Romsdal.csv')

Z3_270520_A3_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z3_270520_A3_Romsdal.csv')
Z3_270520_A4_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z3_270520_A4_Romsdal.csv')
Z3_270520_A5_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z3_270520_A5_Romsdal.csv')
Z3_270520_A6_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z3_270520_A6_Romsdal.csv')
Z3_270520_A7_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z3_270520_A7_Romsdal.csv')
Z3_270520_A8_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z3_270520_A8_Romsdal.csv')

Z3_140220_A3_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z3_140220_A3_Romsdal.csv')
Z3_140220_A4_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z3_140220_A4_Romsdal.csv')
Z3_140220_A5_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z3_140220_A5_Romsdal.csv')
Z3_140220_A6_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z3_140220_A6_Romsdal.csv')
Z3_140220_A7_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z3_140220_A7_Romsdal.csv')
Z3_140220_A8_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z3_140220_A8_Romsdal.csv')

# %%
print(Z3_030420_A3_Romsdal[cols].sum())
print(Z3_030420_A4_Romsdal[cols].sum())
print(Z3_030420_A5_Romsdal[cols].sum())
print(Z3_030420_A6_Romsdal[cols].sum())
print(Z3_030420_A7_Romsdal[cols].sum())
print(Z3_030420_A8_Romsdal[cols].sum())

print(Z3_030520_A3_Romsdal[cols].sum())
print(Z3_030520_A4_Romsdal[cols].sum())
print(Z3_030520_A5_Romsdal[cols].sum())
print(Z3_030520_A6_Romsdal[cols].sum())
print(Z3_030520_A7_Romsdal[cols].sum())
print(Z3_030520_A8_Romsdal[cols].sum())

print(Z3_140520_A3_Romsdal[cols].sum())
print(Z3_140520_A4_Romsdal[cols].sum())
print(Z3_140520_A5_Romsdal[cols].sum())
print(Z3_140520_A6_Romsdal[cols].sum())
print(Z3_140520_A7_Romsdal[cols].sum())
print(Z3_140520_A8_Romsdal[cols].sum())

print(Z3_100120_A3_Romsdal[cols].sum())
print(Z3_100120_A4_Romsdal[cols].sum())
print(Z3_100120_A5_Romsdal[cols].sum())
print(Z3_100120_A6_Romsdal[cols].sum())
print(Z3_100120_A7_Romsdal[cols].sum())
print(Z3_100120_A8_Romsdal[cols].sum())

print(Z3_270520_A3_Romsdal[cols].sum())
print(Z3_270520_A4_Romsdal[cols].sum())
print(Z3_270520_A5_Romsdal[cols].sum())
print(Z3_270520_A6_Romsdal[cols].sum())
print(Z3_270520_A7_Romsdal[cols].sum())
print(Z3_270520_A8_Romsdal[cols].sum())

print(Z3_140220_A3_Romsdal[cols].sum())
print(Z3_140220_A4_Romsdal[cols].sum())
print(Z3_140220_A5_Romsdal[cols].sum())
print(Z3_140220_A6_Romsdal[cols].sum())
print(Z3_140220_A7_Romsdal[cols].sum())
print(Z3_140220_A8_Romsdal[cols].sum())
# Out:
# _count    1368.000000
# _sum      1037.835756
# dtype: float64
# _count    486.000000
# _sum      278.107926
# dtype: float64
# _count    910.000000
# _sum      682.739351
# dtype: float64
# _count    1963.000000
# _sum      1381.875316
# dtype: float64
# _count    0.0
# _sum      0.0
# dtype: float64
# _count    191.000000
# _sum      106.560693
# dtype: float64
# _count    0.0
# _sum      0.0
# dtype: float64
# _count    783.000000
# _sum      411.604558
# dtype: float64
# _count    840.00000
# _sum      461.24284
# dtype: float64
# _count    538.000000
# _sum      217.500161
# dtype: float64
# _count    597.000000
# _sum      298.190338
# dtype: float64
# _count    196.000000
# _sum       50.130156
# dtype: float64
# _count    1718.000000
# _sum      1354.342175
# dtype: float64
# _count    2134.000000
# _sum      1560.834014
# dtype: float64
# _count    1810.000000
# _sum      1291.348277
# dtype: float64
# _count    3268.000000
# _sum      2810.760228
# dtype: float64
# ...

# %% [markdown]
# #### Zone 4 - Region 1011 Romsdal

# %%
Z4_030420_A3_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z4_Z3_030420_A3_Romsdal.csv')
Z4_030420_A4_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z4_Z3_030420_A4_Romsdal.csv')
Z4_030420_A5_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z4_Z3_030420_A5_Romsdal.csv')
Z4_030420_A6_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z4_Z3_030420_A6_Romsdal.csv')
Z4_030420_A7_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z4_Z3_030420_A7_Romsdal.csv')
Z4_030420_A8_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z4_Z3_030420_A8_Romsdal.csv')

Z4_030520_A3_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z4_Z3_030520_A3_Romsdal.csv')
Z4_030520_A4_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z4_Z3_030520_A4_Romsdal.csv')
Z4_030520_A5_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z4_Z3_030520_A5_Romsdal.csv')
Z4_030520_A6_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z4_Z3_030520_A6_Romsdal.csv')
Z4_030520_A7_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z4_Z3_030520_A7_Romsdal.csv')
Z4_030520_A8_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z4_Z3_030520_A8_Romsdal.csv')

Z4_140520_A3_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z4_Z3_140520_A3_Romsdal.csv')
Z4_140520_A4_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z4_Z3_140520_A4_Romsdal.csv')
Z4_140520_A5_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z4_Z3_140520_A5_Romsdal.csv')
Z4_140520_A6_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z4_Z3_140520_A6_Romsdal.csv')
Z4_140520_A7_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z4_Z3_140520_A7_Romsdal.csv')
Z4_140520_A8_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z4_Z3_140520_A8_Romsdal.csv')

Z4_100120_A3_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z4_Z3_100120_A3_Romsdal.csv')
Z4_100120_A4_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z4_Z3_100120_A4_Romsdal.csv')
Z4_100120_A5_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z4_Z3_100120_A5_Romsdal.csv')
Z4_100120_A6_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z4_Z3_100120_A6_Romsdal.csv')
Z4_100120_A7_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z4_Z3_100120_A7_Romsdal.csv')
Z4_100120_A8_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z4_Z3_100120_A8_Romsdal.csv')

Z4_270520_A3_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z4_Z3_270520_A3_Romsdal.csv')
Z4_270520_A4_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z4_Z3_270520_A4_Romsdal.csv')
Z4_270520_A5_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z4_Z3_270520_A5_Romsdal.csv')
Z4_270520_A6_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z4_Z3_270520_A6_Romsdal.csv')
Z4_270520_A7_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z4_Z3_270520_A7_Romsdal.csv')
Z4_270520_A8_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z4_Z3_270520_A8_Romsdal.csv')

Z4_140220_A3_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z4_Z3_140220_A3_Romsdal.csv')
Z4_140220_A4_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z4_Z3_140220_A4_Romsdal.csv')
Z4_140220_A5_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z4_Z3_140220_A5_Romsdal.csv')
Z4_140220_A6_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z4_Z3_140220_A6_Romsdal.csv')
Z4_140220_A7_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z4_Z3_140220_A7_Romsdal.csv')
Z4_140220_A8_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z4_Z3_140220_A8_Romsdal.csv')

# %%
print(Z4_030420_A3_Romsdal[cols].sum())
print(Z4_030420_A4_Romsdal[cols].sum())
print(Z4_030420_A5_Romsdal[cols].sum())
print(Z4_030420_A6_Romsdal[cols].sum())
print(Z4_030420_A7_Romsdal[cols].sum())
print(Z4_030420_A8_Romsdal[cols].sum())

print(Z4_030520_A3_Romsdal[cols].sum())
print(Z4_030520_A4_Romsdal[cols].sum())
print(Z4_030520_A5_Romsdal[cols].sum())
print(Z4_030520_A6_Romsdal[cols].sum())
print(Z4_030520_A7_Romsdal[cols].sum())
print(Z4_030520_A8_Romsdal[cols].sum())

print(Z4_140520_A3_Romsdal[cols].sum())
print(Z4_140520_A4_Romsdal[cols].sum())
print(Z4_140520_A5_Romsdal[cols].sum())
print(Z4_140520_A6_Romsdal[cols].sum())
print(Z4_140520_A7_Romsdal[cols].sum())
print(Z4_140520_A8_Romsdal[cols].sum())

print(Z4_100120_A3_Romsdal[cols].sum())
print(Z4_100120_A4_Romsdal[cols].sum())
print(Z4_100120_A5_Romsdal[cols].sum())
print(Z4_100120_A6_Romsdal[cols].sum())
print(Z4_100120_A7_Romsdal[cols].sum())
print(Z4_100120_A8_Romsdal[cols].sum())

print(Z4_270520_A3_Romsdal[cols].sum())
print(Z4_270520_A4_Romsdal[cols].sum())
print(Z4_270520_A5_Romsdal[cols].sum())
print(Z4_270520_A6_Romsdal[cols].sum())
print(Z4_270520_A7_Romsdal[cols].sum())
print(Z4_270520_A8_Romsdal[cols].sum())

print(Z4_140220_A3_Romsdal[cols].sum())
print(Z4_140220_A4_Romsdal[cols].sum())
print(Z4_140220_A5_Romsdal[cols].sum())
print(Z4_140220_A6_Romsdal[cols].sum())
print(Z4_140220_A7_Romsdal[cols].sum())
print(Z4_140220_A8_Romsdal[cols].sum())
# Out:
# _count    1493.000000
# _sum       631.723843
# dtype: float64
# _count    673.000000
# _sum      255.935376
# dtype: float64
# _count    1064.00000
# _sum       505.60164
# dtype: float64
# _count    2004.00000
# _sum       880.04671
# dtype: float64
# _count    0.0
# _sum      0.0
# dtype: float64
# _count    333.000000
# _sum       84.099814
# dtype: float64
# _count    0.0
# _sum      0.0
# dtype: float64
# _count    1144.000000
# _sum       345.727992
# dtype: float64
# _count    1185.000000
# _sum       224.498001
# dtype: float64
# _count    718.000000
# _sum       75.686956
# dtype: float64
# _count    628.000000
# _sum      187.838179
# dtype: float64
# _count    209.000000
# _sum       32.445614
# dtype: float64
# _count    1329.000000
# _sum       485.576309
# dtype: float64
# _count    1804.000000
# _sum       846.541234
# dtype: float64
# _count    2113.000000
# _sum       675.585802
# dtype: float64
# _count    2271.000000
# _sum       929.322082
# dtype: float64
# ...

# %%
print(Z4_100120_A3_Romsdal[cols].sum())
print(Z4_100120_A4_Romsdal[cols].sum())
print(Z4_100120_A5_Romsdal[cols].sum())
print(Z4_100120_A6_Romsdal[cols].sum())
print(Z4_100120_A7_Romsdal[cols].sum())
print(Z4_100120_A8_Romsdal[cols].sum())
# Out:
# _count    368.00000
# _sum       66.62907
# dtype: float64
# _count    756.000000
# _sum       53.110965
# dtype: float64
# _count    2176.000000
# _sum       282.336159
# dtype: float64
# _count    1529.000000
# _sum       402.796291
# dtype: float64
# _count    0.0
# _sum      0.0
# dtype: float64
# _count    0.0
# _sum      0.0
# dtype: float64

# %% [markdown]
# #### Zone 1 - Region 1016 Lyngen

# %%
Z1_040120_A1_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z1_040120_A1_Lyngen.csv')
Z1_040120_A2_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z1_040120_A2_Lyngen.csv')
Z1_040120_A9_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z1_040120_A9_Lyngen.csv')
Z1_040120_A10_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z1_040120_A10_Lyngen.csv')
Z1_040120_A11_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z1_040120_A11_Lyngen.csv')
Z1_040120_A12_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z1_040120_A12_Lyngen.csv')

Z1_040519_A1_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z1_040519_A1_Lyngen.csv')
Z1_040519_A2_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z1_040519_A2_Lyngen.csv')
Z1_040519_A9_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z1_040519_A9_Lyngen.csv')
Z1_040519_A10_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z1_040519_A10_Lyngen.csv')
Z1_040519_A11_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z1_040519_A11_Lyngen.csv')
Z1_040519_A12_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z1_040519_A12_Lyngen.csv')

Z1_091120_A1_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z1_091120_A1_Lyngen.csv')
Z1_091120_A2_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z1_091120_A2_Lyngen.csv')
Z1_091120_A9_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z1_091120_A9_Lyngen.csv')
Z1_091120_A10_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z1_091120_A10_Lyngen.csv')
Z1_091120_A11_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z1_091120_A11_Lyngen.csv')
Z1_091120_A12_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z1_091120_A12_Lyngen.csv')

Z1_170221_A1_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z1_170221_A1_Lyngen.csv')
Z1_170221_A2_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z1_170221_A2_Lyngen.csv')
Z1_170221_A9_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z1_170221_A9_Lyngen.csv')
Z1_170221_A10_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z1_170221_A10_Lyngen.csv')
Z1_170221_A11_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z1_170221_A11_Lyngen.csv')
Z1_170221_A12_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z1_170221_A12_Lyngen.csv')

Z1_310320_A1_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z1_310320_A1_Lyngen.csv')
Z1_310320_A2_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z1_310320_A2_Lyngen.csv')
Z1_310320_A9_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z1_310320_A9_Lyngen.csv')
Z1_310320_A10_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z1_310320_A10_Lyngen.csv')
Z1_310320_A11_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z1_310320_A11_Lyngen.csv')
Z1_310320_A12_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z1_310320_A12_Lyngen.csv')

Z1_111219_A1_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z1_111219_A1_Lyngen.csv')
Z1_111219_A2_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z1_111219_A2_Lyngen.csv')
Z1_111219_A9_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z1_111219_A9_Lyngen.csv')
Z1_111219_A10_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z1_111219_A10_Lyngen.csv')
Z1_111219_A11_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z1_111219_A11_Lyngen.csv')
Z1_111219_A12_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z1_111219_A12_Lyngen.csv')

# %%
print(Z1_040120_A1_Lyngen[cols].sum())
print(Z1_040120_A2_Lyngen[cols].sum())
print(Z1_040120_A9_Lyngen[cols].sum())
print(Z1_040120_A10_Lyngen[cols].sum())
print(Z1_040120_A11_Lyngen[cols].sum())
print(Z1_040120_A12_Lyngen[cols].sum())

print(Z1_040519_A1_Lyngen[cols].sum())
print(Z1_040519_A2_Lyngen[cols].sum())
print(Z1_040519_A9_Lyngen[cols].sum())
print(Z1_040519_A10_Lyngen[cols].sum())
print(Z1_040519_A11_Lyngen[cols].sum())
print(Z1_040519_A12_Lyngen[cols].sum())

print(Z1_091120_A1_Lyngen[cols].sum())
print(Z1_091120_A2_Lyngen[cols].sum())
print(Z1_091120_A9_Lyngen[cols].sum())
print(Z1_091120_A10_Lyngen[cols].sum())
print(Z1_091120_A11_Lyngen[cols].sum())
print(Z1_091120_A12_Lyngen[cols].sum())

print(Z1_170221_A1_Lyngen[cols].sum())
print(Z1_170221_A2_Lyngen[cols].sum())
print(Z1_170221_A9_Lyngen[cols].sum())
print(Z1_170221_A10_Lyngen[cols].sum())
print(Z1_170221_A11_Lyngen[cols].sum())
print(Z1_170221_A12_Lyngen[cols].sum())

print(Z1_310320_A1_Lyngen[cols].sum())
print(Z1_310320_A2_Lyngen[cols].sum())
print(Z1_310320_A9_Lyngen[cols].sum())
print(Z1_310320_A10_Lyngen[cols].sum())
print(Z1_310320_A11_Lyngen[cols].sum())
print(Z1_310320_A12_Lyngen[cols].sum())

print(Z1_111219_A1_Lyngen[cols].sum())
print(Z1_111219_A2_Lyngen[cols].sum())
print(Z1_111219_A9_Lyngen[cols].sum())
print(Z1_111219_A10_Lyngen[cols].sum())
print(Z1_111219_A11_Lyngen[cols].sum())
print(Z1_111219_A12_Lyngen[cols].sum())
# Out:
# _count    120563.000000
# _sum        9286.899907
# dtype: float64
# _count    55835.000000
# _sum       1206.313635
# dtype: float64
# _count    57928.000000
# _sum        499.185519
# dtype: float64
# _count    99812.000000
# _sum       6466.503072
# dtype: float64
# _count    41335.000000
# _sum       3283.554439
# dtype: float64
# _count    37733.000000
# _sum        716.882183
# dtype: float64
# _count    114021.000000
# _sum       -7121.573906
# dtype: float64
# _count    95175.00000
# _sum      -4685.71524
# dtype: float64
# _count    54040.000000
# _sum        335.264533
# dtype: float64
# _count    90800.000000
# _sum       3299.955923
# dtype: float64
# _count    37813.00000
# _sum      -3069.41506
# dtype: float64
# _count    35517.000000
# _sum      -4195.007044
# dtype: float64
# _count    132669.000000
# _sum       -2996.439599
# dtype: float64
# _count    102563.00000
# _sum          59.83599
# dtype: float64
# _count    57301.00000
# _sum      -1228.46169
# ...

# %% [markdown]
# #### Zone 2 Lyngen

# %%
Z2_040120_A1_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z2_040120_A1_Lyngen.csv')
Z2_040120_A2_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z2_040120_A2_Lyngen.csv')
Z2_040120_A9_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z2_040120_A9_Lyngen.csv')
Z2_040120_A10_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z2_040120_A10_Lyngen.csv')
Z2_040120_A11_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z2_040120_A11_Lyngen.csv')
Z2_040120_A12_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z2_040120_A12_Lyngen.csv')

Z2_040519_A1_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z2_040519_A1_Lyngen.csv')
Z2_040519_A2_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z2_040519_A2_Lyngen.csv')
Z2_040519_A9_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z2_040519_A9_Lyngen.csv')
Z2_040519_A10_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z2_040519_A10_Lyngen.csv')
Z2_040519_A11_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z2_040519_A11_Lyngen.csv')
Z2_040519_A12_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z2_040519_A12_Lyngen.csv')

Z2_091120_A1_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z2_091120_A1_Lyngen.csv')
Z2_091120_A2_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z2_091120_A2_Lyngen.csv')
Z2_091120_A9_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z2_091120_A9_Lyngen.csv')
Z2_091120_A10_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z2_091120_A10_Lyngen.csv')
Z2_091120_A11_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z2_091120_A11_Lyngen.csv')
Z2_091120_A12_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z2_091120_A12_Lyngen.csv')

Z2_170221_A1_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z2_170221_A1_Lyngen.csv')
Z2_170221_A2_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z2_170221_A2_Lyngen.csv')
Z2_170221_A9_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z2_170221_A9_Lyngen.csv')
Z2_170221_A10_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z2_170221_A10_Lyngen.csv')
Z2_170221_A11_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z2_170221_A11_Lyngen.csv')
Z2_170221_A12_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z2_170221_A12_Lyngen.csv')

Z2_310320_A1_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z2_310320_A1_Lyngen.csv')
Z2_310320_A2_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z2_310320_A2_Lyngen.csv')
Z2_310320_A9_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z2_310320_A9_Lyngen.csv')
Z2_310320_A10_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z2_310320_A10_Lyngen.csv')
Z2_310320_A11_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z2_310320_A11_Lyngen.csv')
Z2_310320_A12_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z2_310320_A12_Lyngen.csv')

Z2_111219_A1_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z2_111219_A1_Lyngen.csv')
Z2_111219_A2_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z2_111219_A2_Lyngen.csv')
Z2_111219_A9_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z2_111219_A9_Lyngen.csv')
Z2_111219_A10_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z2_111219_A10_Lyngen.csv')
Z2_111219_A11_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z2_111219_A11_Lyngen.csv')
Z2_111219_A12_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z2_111219_A12_Lyngen.csv')

# %%
print(Z2_040120_A1_Lyngen[cols].sum())
print(Z2_040120_A2_Lyngen[cols].sum())
print(Z2_040120_A9_Lyngen[cols].sum())
print(Z2_040120_A10_Lyngen[cols].sum())
print(Z2_040120_A11_Lyngen[cols].sum())
print(Z2_040120_A12_Lyngen[cols].sum())

print(Z2_040519_A1_Lyngen[cols].sum())
print(Z2_040519_A2_Lyngen[cols].sum())
print(Z2_040519_A9_Lyngen[cols].sum())
print(Z2_040519_A10_Lyngen[cols].sum())
print(Z2_040519_A11_Lyngen[cols].sum())
print(Z2_040519_A12_Lyngen[cols].sum())

print(Z2_091120_A1_Lyngen[cols].sum())
print(Z2_091120_A2_Lyngen[cols].sum())
print(Z2_091120_A9_Lyngen[cols].sum())
print(Z2_091120_A10_Lyngen[cols].sum())
print(Z2_091120_A11_Lyngen[cols].sum())
print(Z2_091120_A12_Lyngen[cols].sum())

print(Z2_170221_A1_Lyngen[cols].sum())
print(Z2_170221_A2_Lyngen[cols].sum())
print(Z2_170221_A9_Lyngen[cols].sum())
print(Z2_170221_A10_Lyngen[cols].sum())
print(Z2_170221_A11_Lyngen[cols].sum())
print(Z2_170221_A12_Lyngen[cols].sum())

print(Z2_310320_A1_Lyngen[cols].sum())
print(Z2_310320_A2_Lyngen[cols].sum())
print(Z2_310320_A9_Lyngen[cols].sum())
print(Z2_310320_A10_Lyngen[cols].sum())
print(Z2_310320_A11_Lyngen[cols].sum())
print(Z2_310320_A12_Lyngen[cols].sum())

print(Z2_111219_A1_Lyngen[cols].sum())
print(Z2_111219_A2_Lyngen[cols].sum())
print(Z2_111219_A9_Lyngen[cols].sum())
print(Z2_111219_A10_Lyngen[cols].sum())
print(Z2_111219_A11_Lyngen[cols].sum())
print(Z2_111219_A12_Lyngen[cols].sum())
# Out:
# _count    508475.741650
# _sum       31223.779499
# dtype: float64
# _count    216176.833974
# _sum       13309.106814
# dtype: float64
# _count    247701.738406
# _sum       19665.139094
# dtype: float64
# _count    402174.637025
# _sum       22069.068117
# dtype: float64
# _count    259120.162711
# _sum       14318.000796
# dtype: float64
# _count    191584.143538
# _sum        9015.994398
# dtype: float64
# _count    468447.613376
# _sum      -14877.684163
# dtype: float64
# _count    292322.179366
# _sum       12490.247913
# dtype: float64
# _count    225579.220241
# _sum        5465.368259
# dtype: float64
# _count    378231.261126
# _sum       36597.053522
# dtype: float64
# _count    249830.339738
# _sum       11109.394326
# dtype: float64
# _count    180527.806340
# _sum        5703.737997
# dtype: float64
# _count    524089.699203
# _sum      -56919.701871
# dtype: float64
# _count    325439.098848
# _sum      -27848.474280
# dtype: float64
# _count    250901.544021
# ...

# %% [markdown]
# #### Zone 3 Lyngen

# %%
Z3_040120_A1_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z3_040120_A1_Lyngen.csv')
Z3_040120_A2_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z3_040120_A2_Lyngen.csv')
Z3_040120_A9_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z3_040120_A9_Lyngen.csv')
Z3_040120_A10_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z3_040120_A10_Lyngen.csv')
Z3_040120_A11_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z3_040120_A11_Lyngen.csv')
Z3_040120_A12_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z3_040120_A12_Lyngen.csv')

Z3_040519_A1_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z3_040519_A1_Lyngen.csv')
Z3_040519_A2_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z3_040519_A2_Lyngen.csv')
Z3_040519_A9_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z3_040519_A9_Lyngen.csv')
Z3_040519_A10_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z3_040519_A10_Lyngen.csv')
Z3_040519_A11_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z3_040519_A11_Lyngen.csv')
Z3_040519_A12_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z3_040519_A12_Lyngen.csv')

Z3_091120_A1_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z3_091120_A1_Lyngen.csv')
Z3_091120_A2_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z3_091120_A2_Lyngen.csv')
Z3_091120_A9_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z3_091120_A9_Lyngen.csv')
Z3_091120_A10_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z3_091120_A10_Lyngen.csv')
Z3_091120_A11_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z3_091120_A11_Lyngen.csv')
Z3_091120_A12_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z3_091120_A12_Lyngen.csv')

Z3_170221_A1_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z3_170221_A1_Lyngen.csv')
Z3_170221_A2_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z3_170221_A2_Lyngen.csv')
Z3_170221_A9_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z3_170221_A9_Lyngen.csv')
Z3_170221_A10_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z3_170221_A10_Lyngen.csv')
Z3_170221_A11_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z3_170221_A11_Lyngen.csv')
Z3_170221_A12_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z3_170221_A12_Lyngen.csv')

Z3_310320_A1_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z3_310320_A1_Lyngen.csv')
Z3_310320_A2_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z3_310320_A2_Lyngen.csv')
Z3_310320_A9_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z3_310320_A9_Lyngen.csv')
Z3_310320_A10_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z3_310320_A10_Lyngen.csv')
Z3_310320_A11_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z3_310320_A11_Lyngen.csv')
Z3_310320_A12_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z3_310320_A12_Lyngen.csv')

Z3_111219_A1_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z3_111219_A1_Lyngen.csv')
Z3_111219_A2_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z3_111219_A2_Lyngen.csv')
Z3_111219_A9_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z3_111219_A9_Lyngen.csv')
Z3_111219_A10_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z3_111219_A10_Lyngen.csv')
Z3_111219_A11_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z3_111219_A11_Lyngen.csv')
Z3_111219_A12_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z3_111219_A12_Lyngen.csv')

# %%
print(Z3_040120_A1_Lyngen[cols].sum())
print(Z3_040120_A2_Lyngen[cols].sum())
print(Z3_040120_A9_Lyngen[cols].sum())
print(Z3_040120_A10_Lyngen[cols].sum())
print(Z3_040120_A11_Lyngen[cols].sum())
print(Z3_040120_A12_Lyngen[cols].sum())

print(Z3_040519_A1_Lyngen[cols].sum())
print(Z3_040519_A2_Lyngen[cols].sum())
print(Z3_040519_A9_Lyngen[cols].sum())
print(Z3_040519_A10_Lyngen[cols].sum())
print(Z3_040519_A11_Lyngen[cols].sum())
print(Z3_040519_A12_Lyngen[cols].sum())

print(Z3_091120_A1_Lyngen[cols].sum())
print(Z3_091120_A2_Lyngen[cols].sum())
print(Z3_091120_A9_Lyngen[cols].sum())
print(Z3_091120_A10_Lyngen[cols].sum())
print(Z3_091120_A11_Lyngen[cols].sum())
print(Z3_091120_A12_Lyngen[cols].sum())

print(Z3_170221_A1_Lyngen[cols].sum())
print(Z3_170221_A2_Lyngen[cols].sum())
print(Z3_170221_A9_Lyngen[cols].sum())
print(Z3_170221_A10_Lyngen[cols].sum())
print(Z3_170221_A11_Lyngen[cols].sum())
print(Z3_170221_A12_Lyngen[cols].sum())

print(Z3_310320_A1_Lyngen[cols].sum())
print(Z3_310320_A2_Lyngen[cols].sum())
print(Z3_310320_A9_Lyngen[cols].sum())
print(Z3_310320_A10_Lyngen[cols].sum())
print(Z3_310320_A11_Lyngen[cols].sum())
print(Z3_310320_A12_Lyngen[cols].sum())

print(Z3_111219_A1_Lyngen[cols].sum())
print(Z3_111219_A2_Lyngen[cols].sum())
print(Z3_111219_A9_Lyngen[cols].sum())
print(Z3_111219_A10_Lyngen[cols].sum())
print(Z3_111219_A11_Lyngen[cols].sum())
print(Z3_111219_A12_Lyngen[cols].sum())
# Out:
# _count    5876.000000
# _sum      2953.979943
# dtype: float64
# _count    1165.000000
# _sum       416.562471
# dtype: float64
# _count    3335.000000
# _sum      1342.116678
# dtype: float64
# _count    1615.157797
# _sum       729.774222
# dtype: float64
# _count    2177.00000
# _sum      1079.04812
# dtype: float64
# _count    1762.00000
# _sum       905.71011
# dtype: float64
# _count    6073.000000
# _sum      4673.680059
# dtype: float64
# _count    1932.000000
# _sum      1333.425052
# dtype: float64
# _count    2631.000000
# _sum      1664.939009
# dtype: float64
# _count    3763.000000
# _sum      2616.533145
# dtype: float64
# _count    3307.000000
# _sum      2188.107556
# dtype: float64
# _count    3435.000000
# _sum      2128.340351
# dtype: float64
# _count    5283.00000
# _sum      2288.57384
# dtype: float64
# _count    728.000000
# _sum      269.903137
# dtype: float64
# _count    1362.000000
# _sum       489.260067
# dtype: float64
# _count    2411.000000
# ...

# %% [markdown]
# #### Zone 4 Lyngen

# %%
Z4_040120_A1_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z4_Z3_040120_A1_Lyngen.csv')
Z4_040120_A2_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z4_Z3_040120_A2_Lyngen.csv')
Z4_040120_A9_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z4_Z3_040120_A9_Lyngen.csv')
Z4_040120_A10_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z4_Z3_040120_A10_Lyngen.csv')
Z4_040120_A11_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z4_Z3_040120_A11_Lyngen.csv')
Z4_040120_A12_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z4_Z3_040120_A12_Lyngen.csv')

Z4_040519_A1_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z4_Z3_040519_A1_Lyngen.csv')
Z4_040519_A2_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z4_Z3_040519_A2_Lyngen.csv')
Z4_040519_A9_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z4_Z3_040519_A9_Lyngen.csv')
Z4_040519_A10_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z4_Z3_040519_A10_Lyngen.csv')
Z4_040519_A11_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z4_Z3_040519_A11_Lyngen.csv')
Z4_040519_A12_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z4_Z3_040519_A12_Lyngen.csv')

Z4_091120_A1_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z4_Z3_091120_A1_Lyngen.csv')
Z4_091120_A2_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z4_Z3_091120_A2_Lyngen.csv')
Z4_091120_A9_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z4_Z3_091120_A9_Lyngen.csv')
Z4_091120_A10_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z4_Z3_091120_A10_Lyngen.csv')
Z4_091120_A11_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z4_Z3_091120_A11_Lyngen.csv')
Z4_091120_A12_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z4_Z3_091120_A12_Lyngen.csv')

Z4_170221_A1_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z4_Z3_170221_A1_Lyngen.csv')
Z4_170221_A2_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z4_Z3_170221_A2_Lyngen.csv')
Z4_170221_A9_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z4_Z3_170221_A9_Lyngen.csv')
Z4_170221_A10_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z4_Z3_170221_A10_Lyngen.csv')
Z4_170221_A11_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z4_Z3_170221_A11_Lyngen.csv')
Z4_170221_A12_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z4_Z3_170221_A12_Lyngen.csv')

Z4_310320_A1_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z4_Z3_310320_A1_Lyngen.csv')
Z4_310320_A2_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z4_Z3_310320_A2_Lyngen.csv')
Z4_310320_A9_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z4_Z3_310320_A9_Lyngen.csv')
Z4_310320_A10_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z4_Z3_310320_A10_Lyngen.csv')
Z4_310320_A11_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z4_Z3_310320_A11_Lyngen.csv')
Z4_310320_A12_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z4_Z3_310320_A12_Lyngen.csv')

Z4_111219_A1_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z4_Z3_111219_A1_Lyngen.csv')
Z4_111219_A2_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z4_Z3_111219_A2_Lyngen.csv')
Z4_111219_A9_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z4_Z3_111219_A9_Lyngen.csv')
Z4_111219_A10_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z4_Z3_111219_A10_Lyngen.csv')
Z4_111219_A11_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z4_Z3_111219_A11_Lyngen.csv')
Z4_111219_A12_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z4_Z3_111219_A12_Lyngen.csv')

# %%
print(Z4_040120_A1_Lyngen[cols].sum())
print(Z4_040120_A2_Lyngen[cols].sum())
print(Z4_040120_A9_Lyngen[cols].sum())
print(Z4_040120_A10_Lyngen[cols].sum())
print(Z4_040120_A11_Lyngen[cols].sum())
print(Z4_040120_A12_Lyngen[cols].sum())

print(Z4_040519_A1_Lyngen[cols].sum())
print(Z4_040519_A2_Lyngen[cols].sum())
print(Z4_040519_A9_Lyngen[cols].sum())
print(Z4_040519_A10_Lyngen[cols].sum())
print(Z4_040519_A11_Lyngen[cols].sum())
print(Z4_040519_A12_Lyngen[cols].sum())

print(Z4_091120_A1_Lyngen[cols].sum())
print(Z4_091120_A2_Lyngen[cols].sum())
print(Z4_091120_A9_Lyngen[cols].sum())
print(Z4_091120_A10_Lyngen[cols].sum())
print(Z4_091120_A11_Lyngen[cols].sum())
print(Z4_091120_A12_Lyngen[cols].sum())

print(Z4_170221_A1_Lyngen[cols].sum())
print(Z4_170221_A2_Lyngen[cols].sum())
print(Z4_170221_A9_Lyngen[cols].sum())
print(Z4_170221_A10_Lyngen[cols].sum())
print(Z4_170221_A11_Lyngen[cols].sum())
print(Z4_170221_A12_Lyngen[cols].sum())

print(Z4_310320_A1_Lyngen[cols].sum())
print(Z4_310320_A2_Lyngen[cols].sum())
print(Z4_310320_A9_Lyngen[cols].sum())
print(Z4_310320_A10_Lyngen[cols].sum())
print(Z4_310320_A11_Lyngen[cols].sum())
print(Z4_310320_A12_Lyngen[cols].sum())

print(Z4_111219_A1_Lyngen[cols].sum())
print(Z4_111219_A2_Lyngen[cols].sum())
print(Z4_111219_A9_Lyngen[cols].sum())
print(Z4_111219_A10_Lyngen[cols].sum())
print(Z4_111219_A11_Lyngen[cols].sum())
print(Z4_111219_A12_Lyngen[cols].sum())
# Out:
# _count    6225.000000
# _sum      1631.480685
# dtype: float64
# _count    1714.000000
# _sum       380.944327
# dtype: float64
# _count    3771.000000
# _sum       849.570445
# dtype: float64
# _count    1942.000000
# _sum       475.923594
# dtype: float64
# _count    2399.000000
# _sum       785.932619
# dtype: float64
# _count    1911.000000
# _sum       557.118141
# dtype: float64
# _count    6023.000000
# _sum      2311.402162
# dtype: float64
# _count    2660.000000
# _sum       812.011406
# dtype: float64
# _count    3457.000000
# _sum      1013.547286
# dtype: float64
# _count    4503.00000
# _sum      1860.22039
# dtype: float64
# _count    3850.000000
# _sum      1433.544876
# dtype: float64
# _count    4139.000000
# _sum      1214.043869
# dtype: float64
# _count    5546.000000
# _sum       924.589119
# dtype: float64
# _count    669.000000
# _sum       94.293722
# dtype: float64
# _count    1340.00000
# _sum       213.88005
# dtype: float64
# _count    2337.00000
# ...

# %% [markdown]
# #### Extra dates:

# %% [markdown]
# ##### Lyngen: 9/12/2019 and 9/4/2019

# %%
import pandas as pd

# %%
Z1_091219_A1_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z1_091219_A1_Lyngen.csv')
Z1_091219_A2_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z1_091219_A2_Lyngen.csv')
Z1_091219_A9_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z1_091219_A9_Lyngen.csv')
Z1_091219_A10_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z1_091219_A10_Lyngen.csv')
Z1_091219_A11_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z1_091219_A11_Lyngen.csv')
Z1_091219_A12_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z1_091219_A12_Lyngen.csv')

Z2_091219_A1_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z2_091219_A1_Lyngen.csv')
Z2_091219_A2_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z2_091219_A2_Lyngen.csv')
Z2_091219_A9_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z2_091219_A9_Lyngen.csv')
Z2_091219_A10_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z2_091219_A10_Lyngen.csv')
Z2_091219_A11_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z2_091219_A11_Lyngen.csv')
Z2_091219_A12_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z2_091219_A12_Lyngen.csv')

Z3_091219_A1_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z3_091219_A1_Lyngen.csv')
Z3_091219_A2_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z3_091219_A2_Lyngen.csv')
Z3_091219_A9_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z3_091219_A9_Lyngen.csv')
Z3_091219_A10_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z3_091219_A10_Lyngen.csv')
Z3_091219_A11_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z3_091219_A11_Lyngen.csv')
Z3_091219_A12_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z3_091219_A12_Lyngen.csv')

Z4_091219_A1_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z4_Z3_091219_A1_Lyngen.csv')
Z4_091219_A2_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z4_Z3_091219_A2_Lyngen.csv')
Z4_091219_A9_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z4_Z3_091219_A9_Lyngen.csv')
Z4_091219_A10_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z4_Z3_091219_A10_Lyngen.csv')
Z4_091219_A11_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z4_Z3_091219_A11_Lyngen.csv')
Z4_091219_A12_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z4_Z3_091219_A12_Lyngen.csv')

# %%
Z1_090419_A1_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z1_090419_A1_Lyngen.csv')
Z1_090419_A2_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z1_090419_A2_Lyngen.csv')
Z1_090419_A9_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z1_090419_A9_Lyngen.csv')
Z1_090419_A10_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z1_090419_A10_Lyngen.csv')
Z1_090419_A11_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z1_090419_A11_Lyngen.csv')
Z1_090419_A12_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z1_090419_A12_Lyngen.csv')

Z2_090419_A1_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z2_090419_A1_Lyngen.csv')
Z2_090419_A2_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z2_090419_A2_Lyngen.csv')
Z2_090419_A9_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z2_090419_A9_Lyngen.csv')
Z2_090419_A10_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z2_090419_A10_Lyngen.csv')
Z2_090419_A11_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z2_090419_A11_Lyngen.csv')
Z2_090419_A12_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z2_090419_A12_Lyngen.csv')

Z3_090419_A1_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z3_090419_A1_Lyngen.csv')
Z3_090419_A2_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z3_090419_A2_Lyngen.csv')
Z3_090419_A9_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z3_090419_A9_Lyngen.csv')
Z3_090419_A10_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z3_090419_A10_Lyngen.csv')
Z3_090419_A11_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z3_090419_A11_Lyngen.csv')
Z3_090419_A12_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z3_090419_A12_Lyngen.csv')

Z4_090419_A1_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z4_Z3_090419_A1_Lyngen.csv')
Z4_090419_A2_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z4_Z3_090419_A2_Lyngen.csv')
Z4_090419_A9_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z4_Z3_090419_A9_Lyngen.csv')
Z4_090419_A10_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z4_Z3_090419_A10_Lyngen.csv')
Z4_090419_A11_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z4_Z3_090419_A11_Lyngen.csv')
Z4_090419_A12_Lyngen = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z4_Z3_090419_A12_Lyngen.csv')

# %%
print(Z1_091219_A1_Lyngen[cols].sum())
print(Z1_091219_A2_Lyngen[cols].sum())
print(Z1_091219_A9_Lyngen[cols].sum())
print(Z1_091219_A10_Lyngen[cols].sum())
print(Z1_091219_A11_Lyngen[cols].sum())
print(Z1_091219_A12_Lyngen[cols].sum())
# Out:
# _count    128762.000000
# _sum        3103.951942
# dtype: float64
# _count    100461.000000
# _sum        5344.752527
# dtype: float64
# _count    57921.00000
# _sum        290.82032
# dtype: float64
# _count    100330.0000
# _sum         447.2766
# dtype: float64
# _count    41647.000000
# _sum        485.155483
# dtype: float64
# _count    38168.000000
# _sum         25.489482
# dtype: float64

# %%
print(Z2_091219_A1_Lyngen[cols].sum())
print(Z2_091219_A2_Lyngen[cols].sum())
print(Z2_091219_A9_Lyngen[cols].sum())
print(Z2_091219_A10_Lyngen[cols].sum())
print(Z2_091219_A11_Lyngen[cols].sum())
print(Z2_091219_A12_Lyngen[cols].sum())
# Out:
# _count    524886.847577
# _sum      -13841.996567
# dtype: float64
# _count    326832.098848
# _sum       -5726.164671
# dtype: float64
# _count    253884.719369
# _sum        -748.646069
# dtype: float64
# _count    425405.977886
# _sum        4352.318276
# dtype: float64
# _count    276059.856168
# _sum        2877.129901
# dtype: float64
# _count    202863.367546
# _sum       -1473.108410
# dtype: float64

# %%
print(Z3_091219_A1_Lyngen[cols].sum())
print(Z3_091219_A2_Lyngen[cols].sum())
print(Z3_091219_A9_Lyngen[cols].sum())
print(Z3_091219_A10_Lyngen[cols].sum())
print(Z3_091219_A11_Lyngen[cols].sum())
print(Z3_091219_A12_Lyngen[cols].sum())
# Out:
# _count    6429.000000
# _sum      2787.472959
# dtype: float64
# _count    991.000000
# _sum      298.438662
# dtype: float64
# _count    4594.000000
# _sum      1973.814447
# dtype: float64
# _count    1693.000000
# _sum       470.420918
# dtype: float64
# _count    1451.000000
# _sum       397.006546
# dtype: float64
# _count    2063.000000
# _sum       789.566781
# dtype: float64

# %%
print(Z4_091219_A1_Lyngen[cols].sum())
print(Z4_091219_A2_Lyngen[cols].sum())
print(Z4_091219_A9_Lyngen[cols].sum())
print(Z4_091219_A10_Lyngen[cols].sum())
print(Z4_091219_A11_Lyngen[cols].sum())
print(Z4_091219_A12_Lyngen[cols].sum())
# Out:
# _count    7889.00000
# _sum       579.86121
# dtype: float64
# _count    1290.000000
# _sum        52.217575
# dtype: float64
# _count    1290.000000
# _sum        52.217575
# dtype: float64
# _count    2319.000000
# _sum       175.004694
# dtype: float64
# _count    2130.000000
# _sum       157.454683
# dtype: float64
# _count    2243.000000
# _sum       222.919123
# dtype: float64

# %%
Z4_091219_A2_Lyngen_check = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z4_Z3_091219_A2_Lyngen_check.csv')
Z4_091219_A9_Lyngen_ckeck = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z4_Z3_091219_A9_Lyngen_check.csv')

print(Z4_091219_A2_Lyngen_check[cols].sum())
print(Z4_091219_A9_Lyngen_ckeck[cols].sum())
# Out:
# _count    1290.000000
# _sum        52.217575
# dtype: float64
# _count    5584.000000
# _sum       607.437526
# dtype: float64

# %% [markdown]
# ##### Romsdal: 2/4/2019 and 3/5/2019

# %%
Z1_020419_A3_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z1_020419_A3_Romsdal.csv')
Z1_020419_A4_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z1_020419_A4_Romsdal.csv')
Z1_020419_A5_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z1_020419_A5_Romsdal.csv')
Z1_020419_A6_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z1_020419_A6_Romsdal.csv')
Z1_020419_A7_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z1_020419_A7_Romsdal.csv')
Z1_020419_A8_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z1_020419_A8_Romsdal.csv')

Z2_020419_A3_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z2_020419_A3_Romsdal.csv')
Z2_020419_A4_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z2_020419_A4_Romsdal.csv')
Z2_020419_A5_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z2_020419_A5_Romsdal.csv')
Z2_020419_A6_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z2_020419_A6_Romsdal.csv')
Z2_020419_A7_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z2_020419_A7_Romsdal.csv')
Z2_020419_A8_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z2_020419_A8_Romsdal.csv')

Z3_020419_A3_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z3_020419_A3_Romsdal.csv')
Z3_020419_A4_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z3_020419_A4_Romsdal.csv')
Z3_020419_A5_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z3_020419_A5_Romsdal.csv')
Z3_020419_A6_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z3_020419_A6_Romsdal.csv')
Z3_020419_A7_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z3_020419_A7_Romsdal.csv')
Z3_020419_A8_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z3_020419_A8_Romsdal.csv')

Z4_020419_A3_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z4_Z3_020419_A3_Romsdal.csv')
Z4_020419_A4_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z4_Z3_020419_A4_Romsdal.csv')
Z4_020419_A5_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z4_Z3_020419_A5_Romsdal.csv')
Z4_020419_A6_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z4_Z3_020419_A6_Romsdal.csv')
Z4_020419_A7_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z4_Z3_020419_A7_Romsdal.csv')
Z4_020419_A8_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z4_Z3_020419_A8_Romsdal.csv')

# %%
Z1_030519_A3_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z1_030519_A3_Romsdal.csv')
Z1_030519_A4_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z1_030519_A4_Romsdal.csv')
Z1_030519_A5_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z1_030519_A5_Romsdal.csv')
Z1_030519_A6_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z1_030519_A6_Romsdal.csv')
Z1_030519_A7_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z1_030519_A7_Romsdal.csv')
Z1_030519_A8_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z1_030519_A8_Romsdal.csv')

Z2_030519_A3_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z2_030519_A3_Romsdal.csv')
Z2_030519_A4_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z2_030519_A4_Romsdal.csv')
Z2_030519_A5_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z2_030519_A5_Romsdal.csv')
Z2_030519_A6_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z2_030519_A6_Romsdal.csv')
Z2_030519_A7_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z2_030519_A7_Romsdal.csv')
Z2_030519_A8_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z2_030519_A8_Romsdal.csv')

Z3_030519_A3_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z3_030519_A3_Romsdal.csv')
Z3_030519_A4_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z3_030519_A4_Romsdal.csv')
Z3_030519_A5_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z3_030519_A5_Romsdal.csv')
Z3_030519_A6_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z3_030519_A6_Romsdal.csv')
Z3_030519_A7_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z3_030519_A7_Romsdal.csv')
Z3_030519_A8_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z3_030519_A8_Romsdal.csv')

Z4_030519_A3_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z4_Z3_030519_A3_Romsdal.csv')
Z4_030519_A4_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z4_Z3_030519_A4_Romsdal.csv')
Z4_030519_A5_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z4_Z3_030519_A5_Romsdal.csv')
Z4_030519_A6_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z4_Z3_030519_A6_Romsdal.csv')
Z4_030519_A7_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z4_Z3_030519_A7_Romsdal.csv')
Z4_030519_A8_Romsdal = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_Z4_Z3_030519_A8_Romsdal.csv')

# %%
print(Z4_030519_A3_Romsdal[cols].sum())
print(Z4_030519_A4_Romsdal[cols].sum())
print(Z4_030519_A5_Romsdal[cols].sum())
print(Z4_030519_A6_Romsdal[cols].sum())
print(Z4_030519_A7_Romsdal[cols].sum())
print(Z4_030519_A8_Romsdal[cols].sum())

print(Z4_020419_A3_Romsdal[cols].sum())
print(Z4_020419_A4_Romsdal[cols].sum())
print(Z4_020419_A5_Romsdal[cols].sum())
print(Z4_020419_A6_Romsdal[cols].sum())
print(Z4_020419_A7_Romsdal[cols].sum())
print(Z4_020419_A8_Romsdal[cols].sum())
# Out:
# _count    3004.000000
# _sum       645.724004
# dtype: float64
# _count    273.000000
# _sum      -83.129414
# dtype: float64
# _count    1676.000000
# _sum       182.613407
# dtype: float64
# _count    2298.000000
# _sum       171.806302
# dtype: float64
# _count    229.000000
# _sum      -50.584105
# dtype: float64
# _count    317.000000
# _sum       67.807279
# dtype: float64
# _count    1278.000000
# _sum       251.792153
# dtype: float64
# _count    549.000000
# _sum      -48.423546
# dtype: float64
# _count    1703.000000
# _sum       152.434602
# dtype: float64
# _count    2245.000000
# _sum       312.930482
# dtype: float64
# _count    0.0
# _sum      0.0
# dtype: float64
# _count    231.00000
# _sum       76.67677
# dtype: float64

# %% [markdown]
# ### High-influential datapoints

# %%
print(Z3_040120_A1_Lyngen[cols].sum())
print(Z3_040120_A2_Lyngen[cols].sum())
print(Z3_040120_A9_Lyngen[cols].sum())
print(Z3_040120_A10_Lyngen[cols].sum())
print(Z3_040120_A11_Lyngen[cols].sum())
print(Z3_040120_A12_Lyngen[cols].sum())

print(Z3_091219_A1_Lyngen[cols].sum())
print(Z3_091219_A2_Lyngen[cols].sum())
print(Z3_091219_A9_Lyngen[cols].sum())
print(Z3_091219_A10_Lyngen[cols].sum())
print(Z3_091219_A11_Lyngen[cols].sum())
print(Z3_091219_A12_Lyngen[cols].sum())
# Out:
# _count    5876.000000
# _sum      2953.979943
# dtype: float64
# _count    1165.000000
# _sum       416.562471
# dtype: float64
# _count    3335.000000
# _sum      1342.116678
# dtype: float64
# _count    1615.157797
# _sum       729.774222
# dtype: float64
# _count    2177.00000
# _sum      1079.04812
# dtype: float64
# _count    1762.00000
# _sum       905.71011
# dtype: float64
# _count    6429.000000
# _sum      2787.472959
# dtype: float64
# _count    991.000000
# _sum      298.438662
# dtype: float64
# _count    4594.000000
# _sum      1973.814447
# dtype: float64
# _count    1693.000000
# _sum       470.420918
# dtype: float64
# _count    1451.000000
# _sum       397.006546
# dtype: float64
# _count    2063.000000
# _sum       789.566781
# dtype: float64

# %% [markdown]
# ### Case studies

# %%
Z1_160119 = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_NONE_L1_160119.csv')
Z2_160119 = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_AT_L1_160119.csv')
Z3_160119 = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_DET_L1_160119.csv')
Z4_160119 = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_B40_L1_160119.csv')

Z1_310519 = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_NONE_L1_310519.csv')
Z2_310519 = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_AT_L1_310519.csv')
Z3_310519 = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_DET_L1_310519.csv')
Z4_310519 = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_B40_L1_310519.csv')

# %%
print(Z1_160119[cols].sum())
print(Z2_160119[cols].sum())
print(Z3_160119[cols].sum())
print(Z4_160119[cols].sum())
# Out:
# _count    133925.000000
# _sum      -21330.496996
# dtype: float64
# _count    524225.704678
# _sum      -24650.019707
# dtype: float64
# _count    5819.000000
# _sum      2433.379539
# dtype: float64
# _count    6284.000000
# _sum       885.304502
# dtype: float64

# %%
print(Z1_310519[cols].sum())
print(Z2_310519[cols].sum())
print(Z3_310519[cols].sum())
print(Z4_310519[cols].sum())
# Out:
# _count    110547.000000
# _sum       28509.503019
# dtype: float64
# _count    455544.669038
# _sum       80715.570098
# dtype: float64
# _count    514.0000
# _sum      456.8221
# dtype: float64
# _count    643.000000
# _sum      507.659287
# dtype: float64

# %%
Z1_090419 = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_NONE_R3_090419.csv')
Z2_090419 = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_AT_R3_090419.csv')
Z3_090419 = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_DET_R3_090419.csv')
Z4_090419 = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_B40_R3_090419.csv')

# %%
print(Z1_090419[cols].sum())
print(Z2_090419[cols].sum())
print(Z3_090419[cols].sum())
print(Z4_090419[cols].sum())
# Out:
# _count    89136.000000
# _sum       8791.338273
# dtype: float64
# _count    424523.795329
# _sum       45412.351121
# dtype: float64
# _count    428.000000
# _sum      126.355007
# dtype: float64
# _count    602.000000
# _sum       46.627838
# dtype: float64

# %%
Z1 = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_NONE_R3_140220AM.csv')
Z2 = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_AT_R3_140220AM.csv')
Z3 = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_DET_R3_140220AM.csv')
Z4 = pd.read_csv(r'CSV-zonalstatistics/CSV/stats_B40_R3_140220AM.csv')



print(Z1[cols].sum())
print(Z2[cols].sum())
print(Z3[cols].sum())
print(Z4[cols].sum())
# Out:
# _count    89369.00000
# _sum        314.55899
# dtype: float64
# _count    424490.807812
# _sum      -11129.420185
# dtype: float64
# _count    1496.000000
# _sum       446.761367
# dtype: float64
# _count    2012.000000
# _sum       208.097899
# dtype: float64
