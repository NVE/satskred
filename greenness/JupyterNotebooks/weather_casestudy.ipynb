# %%
import datetime
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import matplotlib.transforms as transforms
import numpy as np

# %%
#Lyngen weather data


df_32_3 = pd.read_excel('/Users/mariaflaten/Documents/UiO/MASTER/QIS-project/VS Code/weather_timeseries_L1/weather_L1.xlsx', sheet_name='32_3h')
df_32_24 = pd.read_excel('/Users/mariaflaten/Documents/UiO/MASTER/QIS-project/VS Code/weather_timeseries_L1/weather_L1.xlsx', sheet_name='32_24h')

df_671_3 = pd.read_excel('/Users/mariaflaten/Documents/UiO/MASTER/QIS-project/VS Code/weather_timeseries_L1/weather_L1.xlsx', sheet_name='671_3h')
df_671_24 = pd.read_excel('/Users/mariaflaten/Documents/UiO/MASTER/QIS-project/VS Code/weather_timeseries_L1/weather_L1.xlsx', sheet_name='671_24h')

df_1244_3 = pd.read_excel('/Users/mariaflaten/Documents/UiO/MASTER/QIS-project/VS Code/weather_timeseries_L1/weather_L1.xlsx', sheet_name='1244_3h')
df_1244_24 = pd.read_excel('/Users/mariaflaten/Documents/UiO/MASTER/QIS-project/VS Code/weather_timeseries_L1/weather_L1.xlsx', sheet_name='1244_24h')

# %%
temp_32 = df_32_3['temp']
wind_32 = df_32_3['wind']
sd_32 = df_32_24['sd']
prec_32 = df_32_24['prec']

temp_671 = df_671_3['temp']
wind_671 = df_671_3['wind']
sd_671 = df_671_24['sd']
prec_671 = df_671_24['prec']

temp_1244 = df_1244_3['temp']
wind_1244 = df_1244_3['wind']
sd_1244 = df_1244_24['sd']
prec_1244 = df_1244_24['prec']

t1 = df_32_3['Date']
t2 = df_32_24['Date']

# %%
months = mdates.MonthLocator()  # every month
days = mdates.DayLocator()       # every day
hour = mdates.HourLocator()       # every hour
myFmt = mdates.DateFormatter('%d.%m.%Y')

# %%
#Romsdal weather data

df_135_3 = pd.read_excel('/Users/mariaflaten/Documents/UiO/MASTER/QIS-project/VS Code/weater_R3.xlsx', sheet_name='3H_135')
df_135_24 = pd.read_excel('/Users/mariaflaten/Documents/UiO/MASTER/QIS-project/VS Code/weater_R3.xlsx', sheet_name='24H_135')

df_687_3 = pd.read_excel('/Users/mariaflaten/Documents/UiO/MASTER/QIS-project/VS Code/weater_R3.xlsx', sheet_name='3H_687')
df_687_24 = pd.read_excel('/Users/mariaflaten/Documents/UiO/MASTER/QIS-project/VS Code/weater_R3.xlsx', sheet_name='24H_687')

df_1685_3 = pd.read_excel('/Users/mariaflaten/Documents/UiO/MASTER/QIS-project/VS Code/weater_R3.xlsx', sheet_name='3H_1685')
df_1685_24 = pd.read_excel('/Users/mariaflaten/Documents/UiO/MASTER/QIS-project/VS Code/weater_R3.xlsx', sheet_name='24H_1685')

# %%
temp_135 = df_135_3['temp']
wind_135 = df_135_3['wind']
sd_135 = df_135_24['sd']
prec_135 = df_135_24['prec']

temp_687 = df_687_3['temp']
wind_687 = df_687_3['wind']
sd_687 = df_687_24['sd']
prec_687 = df_687_24['prec']

temp_1685 = df_1685_3['temp']
wind_1685 = df_1685_3['wind']
sd_1685 = df_1685_24['sd']
prec_1685 = df_1685_24['prec']

t1 = df_135_3['Date']
t2 = df_135_24['Date']

danger_r = df_135_24['danger']
danger_l = df_32_24['danger']

# %%
# Avalanche dates

#Case A1
A11 = datetime.datetime(2019,5,30, 6,20,00)

#Case A2
A21 = datetime.datetime(2020,2,11, 23,58,00)
A22 = datetime.datetime(2020,2,11, 18,20,00)
A23 = datetime.datetime(2020,2,13, 18,29,00)


#Case A3
A31 = datetime.datetime(2019,4,9, 12,25,00)
A32 = datetime.datetime(2019,4,9, 6,6,00)

#########################################

#Case B1
B11 = datetime.datetime(2020,4,29, 23,38,00)
B12 = datetime.datetime(2020,4,29, 18,23,00)

#Case A2
B21 = datetime.datetime(2019,1,16, 4,41,00)

#Case A3
B31 = datetime.datetime(2020,5,12, 12,24,00) 
B32 = datetime.datetime(2020,5,14, 18,51,00) 
B33 = datetime.datetime(2020,5,15, 00,28,00)

# %%
# Satellite passing date-time
x1 = datetime.datetime(2019,1,16, 16,7,00)
x0 = datetime.datetime(2019,1,10, 16,7,00)

# Start- and end-date on x-axis
start = datetime.datetime(2019,1,10)
end = datetime.datetime(2019,1,17)

# Save file as
file = './B2_160119.png' #C1_DDMMYY


# Colors
b = 'blue'      # Blue lines: reference and activity image for passing satellite + relative orbit
bc = 'black'    # Black lines: passing satellite + relative orbit
r = 'red'       # Red lines: time of avalanche release

# %%
fig, (ax1, ax2, ax3) = plt.subplots(3, 1, figsize=(30,20), sharex=True)

#NB! Change y-axis from Lyngen/Romsdal
ax1.plot(t1, temp_32,color='#bae4bc', linewidth=3)
ax1.plot(t1, temp_671, color='#7bccc4', linewidth=3)
ax1.plot(t1, temp_1244, color='#2b8cbe', linewidth=3)

ax2.plot(t1, wind_32,color='#bae4bc', label='32 masl.', linewidth=3)
ax2.plot(t1, wind_671, color='#7bccc4',label='671 masl.', linewidth=3)
ax2.plot(t1, wind_1244, color='#2b8cbe', label='1244 masl.',linewidth=3)

ax3.bar(t2,prec_671, color='#7bccc4')

# Formatting X-axis with small lines per day
ax1.xaxis.set_major_locator(days)
ax1.xaxis.set_major_formatter(myFmt)
ax1.xaxis.set_minor_locator(hour)
plt.setp(ax3.get_xticklabels(), rotation=30, ha="right")

# Subplot labels
ax1.grid()
ax1.set_title('Average air temperature (3 hours) [℃]')
ax1.set_ylabel('[℃]')
ax1.set_ylim([-20, 20])
ax1.axhline(y=0, c='black',linestyle='-',linewidth=2)

ax2.grid()
ax2.set_title('Average wind speed at 10m (3 hours) [m/s]')
ax2.set_ylabel('[m/s]')
ax2.set_ylim([0, 30])

ax3.grid()
ax3.set_title('Precipitation last 24 hours [mm]')
ax3.set_ylabel('[mm]')
ax3.set_ylim([0, 60])

#ax4.grid()
#ax4.set_title('Snowdepth [cm]')
#ax4.set_ylabel('[cm]')
#ax4.set_xlabel('Date')
#ax4.set_ylim([0, 400])



# X-axis is date-time.
plt.xlim(start, end)

plt.rcParams.update({'font.size': 30})

for ax in [ax1, ax2, ax3]:
    ax.axvline(x=x1, c=bc, linestyle='--',linewidth=4)
    ax.axvline(x=x0, c=bc, linestyle='--',linewidth=4)

    ax.axvline(x=B21, c=r,linestyle='dotted',linewidth=4)
    #ax.axvline(x=B12, c=r,linestyle='dotted',linewidth=4)
    #ax.axvline(x=B33, c=r,linestyle='dotted',linewidth=4)
    #ax.axvline(x=x10, c=bc,linestyle='--',linewidth=4)
    trans = transforms.blended_transform_factory(ax.transData, ax.transAxes)

# Labels to lines with relative orbit number
plt.text(x1, 0, 'ACT', transform=trans)
plt.text(x0, 0, 'REF', transform=trans)
plt.text(B21, 0, 'AR', transform=trans, rotation='vertical')
#plt.text(B12, 0, 'AR', transform=trans, rotation='vertical')
#plt.text(B33, 0, 'AR', transform=trans, rotation='vertical')


leg = ax2.legend(loc="upper center", bbox_to_anchor=(0.5, -1.55),fancybox=True, shadow=True, ncol=3)
for line in leg.get_lines():
    line.set_linewidth(6.0)

plt.show()

fig.savefig(file, bbox_inches='tight')
# Out:
# Locator attempting to generate 1038 ticks ([17789.0, ..., 18826.0]), which exceeds Locator.MAXTICKS (1000).
# Locator attempting to generate 24896 ticks ([17788.708333333332, ..., 18826.0]), which exceeds Locator.MAXTICKS (1000).
# Locator attempting to generate 1038 ticks ([17789.0, ..., 18826.0]), which exceeds Locator.MAXTICKS (1000).
# Locator attempting to generate 1038 ticks ([17789.0, ..., 18826.0]), which exceeds Locator.MAXTICKS (1000).

# %% [markdown]
# ### DANGER

# %%
danger = pd.read_excel('/Users/mariaflaten/Documents/UiO/MASTER/QIS-project/VS Code/varsom_dangerlevel.xlsx')

danger
# Out:
#           Date  danger_r  danger_l
# 0   2018-11-01         0         0
# 1   2018-11-02         0         0
# 2   2018-11-03         0         0
# 3   2018-11-04         0         0
# 4   2018-11-05         0         0
# ..         ...       ...       ...
# 938 2021-05-27         2         1
# 939 2021-05-28         2         1
# 940 2021-05-29         2         1
# 941 2021-05-30         1         1
# 942 2021-05-31         1         1
#
# [943 rows x 3 columns]

# %%
import seaborn as sns

# %%
t = danger['Date']
l = danger['danger_l']
r = danger['danger_r']

# %%
# Start- and end-date on x-axis
start = datetime.datetime(2020, 2, 7)
end = datetime.datetime(2020, 2,16)


# Save file as
file = './test.png'

# %%
fig, ax = plt.subplots(figsize=(15,7))

#ax = sns.scatterplot(y=r, x=t, hue=r, size=r, sizes=(10,450), palette=['#ffffff', '#d3de76', '#feec01', '#f6a21c', '#cd1e16'], legend=False)
ax.bar(t, r)

# Y-axis with meteorological data

plt.setp(ax.get_xticklabels(), rotation=30, ha="right")

# Subplot labels
ax1.grid()
ax1.set_ylabel('Avalanche danger level')
ax1.set_ylim([0, 6])

#plt.legend(bbox_to_anchor=(0.25, -0.6, 0.5, 0.2), loc="lower left",
                #mode="expand", borderaxespad=0, ncol=6)


plt.rcParams.update({'font.size': 20})


# X-axis is date-time.
plt.xlim(start, end)



plt.show()

fig.savefig(file, bbox_inches='tight')
